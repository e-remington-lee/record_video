# %%
import tensorflow as tf
import os
import zipfile
from os import path, getcwd, chdir

# DO NOT CHANGE THE LINE BELOW. If you are developing in a local
# environment, then grab happy-or-sad.zip from the Coursera Jupyter Notebook
# and place it inside a local folder and edit the path to that location
path = f"./happy_sad.zip"

with zipfile.ZipFile(path, 'r') as zip_ref:
    zip_ref.extractall("/tmp/")

# %%
sad = os.listdir("/tmp/happy")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img_list = [os.path.join("/tmp/happy", f) for f in sad[0:10]]
print(img_list)

fig = plt.gcf()
fig.set_size_inches(16,16)

for i, x in enumerate(img_list):
    sb = plt.subplot(4,4, i+1)
    sb.axis("Off")
    
    img = mpimg.imread(x)
    plt.imshow(img)
plt.show()
# Out:
# ['/tmp/happy\\happy1-00.png', '/tmp/happy\\happy1-01.png', '/tmp/happy\\happy1-02.png', '/tmp/happy\\happy1-03.png', '/tmp/happy\\happy1-04.png', '/tmp/happy\\happy1-05.png', '/tmp/happy\\happy1-06.png', '/tmp/happy\\happy1-07.png', '/tmp/happy\\happy1-08.png', '/tmp/happy\\happy1-09.png']
